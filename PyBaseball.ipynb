# %%
from config import db_password
from pybaseball import bwar_bat
from pybaseball import batting_stats_range
from pybaseball import playerid_reverse_lookup
from sqlalchemy import create_engine
import pandas as pd 
import psycopg2
import warnings

# %% [markdown]
# ## Create the DataFrame

# %% [markdown]
# ##### Timeframe

# %%
start_year = 2008
end_year = 2021

# %% [markdown]
# ### Player Awards
# Up-To-Date data from [Sean Lahman](https://www.seanlahman.com/baseball-archive/statistics/)

# %%
awards = pd.read_csv('Resources/AwardsPlayers.csv').drop(columns=['tie','notes'])
mvp_awards = awards.sort_values('yearID').loc[
    (awards['yearID'] >= start_year) & (awards['awardID'] == 'Most Valuable Player')]
mvp_awards.head()
# Out:
#        playerID               awardID  yearID lgID
# 5641  pujolal01  Most Valuable Player    2008   NL
# 5640  pedrodu01  Most Valuable Player    2008   AL
# 5703  pujolal01  Most Valuable Player    2009   NL
# 5702  mauerjo01  Most Valuable Player    2009   AL
# 5765  vottojo01  Most Valuable Player    2010   NL

# %% [markdown]
# #### MVP names based on ID

# %%
def reverseLookup(mvp_awards):
    player_names = playerid_reverse_lookup(mvp_awards['playerID'], key_type='bbref')
    player_names['Name'] = player_names['name_first'].map(
        lambda x: x.title()) + ' ' + player_names['name_last'].map(lambda x: x.title())
    player_names = player_names[['Name', 'key_bbref','mlb_played_first', 'mlb_played_last']]
    return player_names.merge(mvp_awards, left_on= 'key_bbref', right_on='playerID').drop(['key_bbref'], axis=1)

mvp_awards = reverseLookup(mvp_awards)
all_awards = reverseLookup(awards)
mvp_awards.head()
# Out:
# Gathering player lookup table. This may take a moment.
#              Name  mlb_played_first  mlb_played_last   playerID  \
# 0      José Abreu            2014.0           2022.0  abreujo02
# 1     Jose Altuve            2011.0           2022.0  altuvjo01
# 2  Cody Bellinger            2017.0           2022.0  bellico01
# 3    Mookie Betts            2014.0           2022.0  bettsmo01
# 4      Ryan Braun            2007.0           2020.0  braunry02
#
#                 awardID  yearID lgID
# 0  Most Valuable Player    2020   AL
# 1  Most Valuable Player    2017   AL
# 2  Most Valuable Player    2019   NL
# 3  Most Valuable Player    2018   AL
# 4  Most Valuable Player    2011   NL

# %%
all_awards.head()
# Out:
#          Name  mlb_played_first  mlb_played_last   playerID  \
# 0  Hank Aaron            1954.0           1976.0  aaronha01
# 1  Hank Aaron            1954.0           1976.0  aaronha01
# 2  Hank Aaron            1954.0           1976.0  aaronha01
# 3  Hank Aaron            1954.0           1976.0  aaronha01
# 4  Hank Aaron            1954.0           1976.0  aaronha01
#
#                   awardID  yearID lgID
# 0            TSN All-Star    1956   ML
# 1  TSN Player of the Year    1956   NL
# 2    Most Valuable Player    1957   NL
# 3              Gold Glove    1958   NL
# 4            TSN All-Star    1958   ML

# %% [markdown]
# ### Merge awards and players dataframes

# %%
warnings.simplefilter('ignore')


def Merger(start_year, end_year, mvp_awards, all_awards, league_type):
    war = bwar_bat()  

    for i in range(end_year-start_year +1):
        current_year = start_year + i
        if i < 1:
            data = getPlayersYearStats(current_year, war, league_type)
            mvpChecker(data, 'Name', mvp_awards, current_year, league_type)
            data = addAllAwards(data, all_awards, current_year)
        else:
            new_data = getPlayersYearStats(current_year, war, league_type)
            mvpChecker(new_data, 'Name', mvp_awards, current_year, league_type)
            new_data = addAllAwards(new_data, all_awards, current_year)
            data = pd.concat([data, new_data])
    return teamClean(data)



def getPlayersYearStats(current_year, war, league_type):
    war = war.loc[war['year_ID'] == current_year][['year_ID','name_common','WAR']]
    batting_stats = batting_stats_range(str(current_year)+'-04-07', str(current_year)+'-10-05').merge(
        war, how='left', left_on='Name', right_on='name_common').drop(['name_common', 'GDP','SH'], axis=1)
    batting_stats['Lev'] = batting_stats['Lev'].map(lambda x: x.split(',')[-1])
    return batting_stats.loc[batting_stats['Lev'] == league_type]

def mvpChecker(data, column, mvp_awards, current_year, league_type):
    for mvp in mvp_awards[column].loc[
        (mvp_awards['yearID'] == current_year) & (mvp_awards['lgID'] == league_type.split('-')[-1])]:
        data['MVP'] = data[column].map(lambda x: categorizer(mvp, x))
        
def addAllAwards(data, all_awards, current_year):
    data = data.merge(all_awards.loc[all_awards['yearID'] == current_year][
        ['Name','awardID']], how='left', on='Name')
    data['awardID'] = data['awardID'].fillna('No Award')
    data['WAR'] = data['WAR'].fillna(0)   
    return data

def teamClean(data):
    data['Tm'] = data['Tm'].map(lambda x: x.split(',')[-1])
    return data

def categorizer(mvp, player):
        if mvp == player:
            return 1
        else:
            return 0

## Add: WRC+

data_NL = Merger(start_year, end_year, mvp_awards, all_awards, 'Maj-NL')

data_NL.head()
# Out:
#                  Name  Age  #days     Lev          Tm   G  PA  AB   R   H  \
# 0  Reggie Abercrombie   27   5062  Maj-NL     Houston  32  60  55  10  17
# 1        Manny Acosta   27   5146  Maj-NL     Atlanta   4   5   5   0   0
# 2          Mike Adams   29   5091  Maj-NL   San Diego   2   2   2   0   0
# 3      Jeremy Affeldt   29   5227  Maj-NL  Cincinnati   1   1   1   0   0
# 4        Chris Aguila   29   5142  Maj-NL    New York   8  15  12   0   2
#
#    ...  SB  CS     BA    OBP    SLG    OPS  year_ID   WAR  MVP   awardID
# 0  ...   5   2  0.309  0.339  0.509  0.848   2008.0  0.42    0  No Award
# 1  ...   0   0  0.000  0.000  0.000  0.000   2008.0 -0.05    0  No Award
# 2  ...   0   0  0.000  0.000  0.000  0.000   2008.0 -0.03    0  No Award
# 3  ...   0   0  0.000  0.000  0.000  0.000   2008.0 -0.01    0  No Award
# 4  ...   0   0  0.167  0.286  0.167  0.452   2008.0 -0.18    0  No Award
#
# [5 rows x 29 columns]

# %%
data_AL = Merger(start_year, end_year, mvp_awards, all_awards, 'Maj-AL')

data_AL.head()
# Out:
#               Name  Age  #days     Lev           Tm    G   PA   AB   R    H  \
# 0    David Aardsma   26   5154  Maj-AL       Boston    1    1    1   0    0
# 1      Bobby Abreu   34   5062  Maj-AL     New York  150  660  587  97  173
# 2   Brian Anderson   26   5060  Maj-AL      Chicago   84  191  179  24   42
# 3  Garret Anderson   36   5062  Maj-AL  Los Angeles  136  563  528  63  154
# 4    Joaquin Arias   23   5063  Maj-AL        Texas   30  120  110  15   32
#
#    ...  SB  CS     BA    OBP    SLG    OPS  year_ID   WAR  MVP   awardID
# 0  ...   0   0  0.000  0.000  0.000  0.000   2008.0 -0.02    0  No Award
# 1  ...  22   7  0.295  0.371  0.475  0.847   2008.0  2.67    0  No Award
# 2  ...   5   1  0.235  0.275  0.441  0.716   2008.0  0.78    0  No Award
# 3  ...   7   2  0.292  0.325  0.428  0.753   2008.0  0.85    0  No Award
# 4  ...   4   1  0.291  0.345  0.409  0.754   2008.0  0.28    0  No Award
#
# [5 rows x 29 columns]

# %% [markdown]
# ### NL MVP Check

# %%
def mvpChecker(data):
    mvp_check = data.loc[data['MVP'] == 1]
    print('There are/is '+str(mvp_check['Name'].nunique())+' unique mvps')
    print(mvp_check['Name'].unique())
    return mvp_check
mvpChecker(data_NL)
# Out:
# There are/is 10 unique mvps
# ['Albert Pujols' 'Joey Votto' 'Ryan Braun' 'Buster Posey'
#  'Clayton Kershaw' 'Giancarlo Stanton' 'Christian Yelich' 'Cody Bellinger'
#  'Freddie Freeman' 'Bryce Harper']
#                   Name  Age  #days     Lev             Tm    G   PA   AB    R  \
# 512      Albert Pujols   28   5062  Maj-NL      St. Louis  141  616  507   98
# 513      Albert Pujols   28   5062  Maj-NL      St. Louis  141  616  507   98
# 514      Albert Pujols   28   5062  Maj-NL      St. Louis  141  616  507   98
# 515      Albert Pujols   28   5062  Maj-NL      St. Louis  141  616  507   98
# 498      Albert Pujols   29   4691  Maj-NL      St. Louis  159  695  564  124
# 499      Albert Pujols   29   4691  Maj-NL      St. Louis  159  695  564  124
# 500      Albert Pujols   29   4691  Maj-NL      St. Louis  159  695  564  124
# 501      Albert Pujols   29   4691  Maj-NL      St. Louis  159  695  564  124
# 502      Albert Pujols   29   4691  Maj-NL      St. Louis  159  695  564  124
# 613         Joey Votto   26   4327  Maj-NL     Cincinnati  148  643  542  104
# 614         Joey Votto   26   4327  Maj-NL     Cincinnati  148  643  542  104
# 60          Ryan Braun   27   3967  Maj-NL      Milwaukee  144  604  543  104
# 61          Ryan Braun   27   3967  Maj-NL      Milwaukee  144  604  543  104
# 479       Buster Posey   25   3596  Maj-NL  San Francisco  147  605  526   78
# 480       Buster Posey   25   3596  Maj-NL  San Francisco  147  605  526   78
# 481       Buster Posey   25   3596  Maj-NL  San Francisco  147  605  526   78
# 482       Buster Posey   25   3596  Maj-NL  San Francisco  147  605  526   78
# 288    Clayton Kershaw   26   2875  Maj-NL    Los Angeles   24   71   60    5
# 289    Clayton Kershaw   26   2875  Maj-NL    Los Angeles   24   71   60    5
# 290    Clayton Kershaw   26   2875  Maj-NL    Los Angeles   24   71   60    5
# 528  Giancarlo Stanton   27   1772  Maj-NL          Miami  156  679  584  122
# 529  Giancarlo Stanton   27   1772  Maj-NL          Miami  156  679  584  122
# 530  Giancarlo Stanton   27   1772  Maj-NL          Miami  156  679  584  122
# 531  Giancarlo Stanton   27   1772  Maj-NL          Miami  156  679  584  122
# 660   Christian Yelich   26   1407  Maj-NL      Milwaukee  141  624  548  112
# 661   Christian Yelich   26   1407  Maj-NL      Milwaukee  141  624  548  112
# 662   Christian Yelich   26   1407  Maj-NL      Milwaukee  141  624  548  112
# 663   Christian Yelich   26   1407  Maj-NL      Milwaukee  141  624  548  112
# 55      Cody Bellinger   23   1044  Maj-NL    Los Angeles  147  619  519  108
# 56      Cody Bellinger   23   1044  Maj-NL    Los Angeles  147  619  519  108
# 57      Cody Bellinger   23   1044  Maj-NL    Los Angeles  147  619  519  108
# 58      Cody Bellinger   23   1044  Maj-NL    Los Angeles  147  619  519  108
# 110    Freddie Freeman   30    680  Maj-NL        Atlanta   60  262  214   51
# 111    Freddie Freeman   30    680  Maj-NL        Atlanta   60  262  214   51
# 112    Freddie Freeman   30    680  Maj-NL        Atlanta   60  262  214   51
# 113    Freddie Freeman   30    680  Maj-NL        Atlanta   60  262  214   51
# 275       Bryce Harper   28    309  Maj-NL   Philadelphia  136  577  473   99
# 276       Bryce Harper   28    309  Maj-NL   Philadelphia  136  577  473   99
# 277       Bryce Harper   28    309  Maj-NL   Philadelphia  136  577  473   99
# 278       Bryce Harper   28    309  Maj-NL   Philadelphia  136  577  473   99
#
#        H  ...  SB  CS     BA    OBP    SLG    OPS  year_ID   WAR  MVP  \
# 512  181  ...   6   2  0.357  0.458  0.659  1.117   2008.0  9.24    1
# 513  181  ...   6   2  0.357  0.458  0.659  1.117   2008.0  9.24    1
# 514  181  ...   6   2  0.357  0.458  0.659  1.117   2008.0  9.24    1
# 515  181  ...   6   2  0.357  0.458  0.659  1.117   2008.0  9.24    1
# 498  183  ...  16   3  0.325  0.440  0.656  1.096   2009.0  9.73    1
# 499  183  ...  16   3  0.325  0.440  0.656  1.096   2009.0  9.73    1
# 500  183  ...  16   3  0.325  0.440  0.656  1.096   2009.0  9.73    1
# 501  183  ...  16   3  0.325  0.440  0.656  1.096   2009.0  9.73    1
# 502  183  ...  16   3  0.325  0.440  0.656  1.096   2009.0  9.73    1
# 613  174  ...  16   4  0.321  0.423  0.594  1.017   2010.0  6.97    1
# 614  174  ...  16   4  0.321  0.423  0.594  1.017   2010.0  6.97    1
# 60   180  ...  33   5  0.332  0.394  0.595  0.989   2011.0  7.74    1
# 61   180  ...  33   5  0.332  0.394  0.595  0.989   2011.0  7.74    1
# 479  176  ...   1   1  0.335  0.407  0.549  0.956   2012.0  7.56    1
# 480  176  ...   1   1  0.335  0.407  0.549  0.956   2012.0  7.56    1
# 481  176  ...   1   1  0.335  0.407  0.549  0.956   2012.0  7.56    1
# 482  176  ...   1   1  0.335  0.407  0.549  0.956   2012.0  7.56    1
# 288   10  ...   1   0  0.167  0.231  0.200  0.431   2014.0  0.49    1
# 289   10  ...   1   0  0.167  0.231  0.200  0.431   2014.0  0.49    1
# 290   10  ...   1   0  0.167  0.231  0.200  0.431   2014.0  0.49    1
# 528  165  ...   2   2  0.283  0.379  0.639  1.017   2017.0  7.93    1
# 529  165  ...   2   2  0.283  0.379  0.639  1.017   2017.0  7.93    1
# 530  165  ...   2   2  0.283  0.379  0.639  1.017   2017.0  7.93    1
# 531  165  ...   2   2  0.283  0.379  0.639  1.017   2017.0  7.93    1
# 660  177  ...  22   4  0.323  0.402  0.599  1.001   2018.0  7.26    1
# 661  177  ...  22   4  0.323  0.402  0.599  1.001   2018.0  7.26    1
# 662  177  ...  22   4  0.323  0.402  0.599  1.001   2018.0  7.26    1
# 663  177  ...  22   4  0.323  0.402  0.599  1.001   2018.0  7.26    1
# 55   153  ...  14   4  0.295  0.402  0.603  1.005   2019.0  8.63    1
# 56   153  ...  14   4  0.295  0.402  0.603  1.005   2019.0  8.63    1
# 57   153  ...  14   4  0.295  0.402  0.603  1.005   2019.0  8.63    1
# 58   153  ...  14   4  0.295  0.402  0.603  1.005   2019.0  8.63    1
# 110   73  ...   2   0  0.341  0.462  0.640  1.102   2020.0  3.30    1
# 111   73  ...   2   0  0.341  0.462  0.640  1.102   2020.0  3.30    1
# 112   73  ...   2   0  0.341  0.462  0.640  1.102   2020.0  3.30    1
# 113   73  ...   2   0  0.341  0.462  0.640  1.102   2020.0  3.30    1
# 275  148  ...  13   3  0.313  0.428  0.628  1.056   2021.0  5.86    1
# 276  148  ...  13   3  0.313  0.428  0.628  1.056   2021.0  5.86    1
# 277  148  ...  13   3  0.313  0.428  0.628  1.056   2021.0  5.86    1
# 278  148  ...  13   3  0.313  0.428  0.628  1.056   2021.0  5.86    1
#
#                                  awardID
# 512                 Most Valuable Player
# 513               Roberto Clemente Award
# 514                       Silver Slugger
# 515  TSN Major League Player of the Year
# 498                     Hank Aaron Award
# 499            Lou Gehrig Memorial Award
# 500                 Most Valuable Player
# 501                       Silver Slugger
# 502  TSN Major League Player of the Year
# 613                     Hank Aaron Award
# 614                 Most Valuable Player
# 60                  Most Valuable Player
# 61                        Silver Slugger
# 479          Comeback Player of the Year
# 480                     Hank Aaron Award
# 481                 Most Valuable Player
# 482                       Silver Slugger
# 288                       Cy Young Award
# 289                 Most Valuable Player
# 290  TSN Major League Player of the Year
# 528                 Most Valuable Player
# 529                     Hank Aaron Award
# 530                       Silver Slugger
# 531                         TSN All-Star
# 660                 Most Valuable Player
# 661                     Hank Aaron Award
# 662                       Silver Slugger
# 663                         TSN All-Star
# 55                  Most Valuable Player
# 56                        Silver Slugger
# 57                            Gold Glove
# 58                          TSN All-Star
# 110                 Most Valuable Player
# 111                     Hank Aaron Award
# 112                       Silver Slugger
# 113                         TSN All-Star
# 275                 Most Valuable Player
# 276                     Hank Aaron Award
# 277                       Silver Slugger
# 278                         TSN All-Star
#
# [40 rows x 29 columns]

# %% [markdown]
# ### AL MVP Check

# %%
mvpChecker(data_AL)
# Out:
# There are/is 10 unique mvps
# ['Dustin Pedroia' 'Joe Mauer' 'Josh Hamilton' 'Justin Verlander'
#  'Miguel Cabrera' 'Mike Trout' 'Jose Altuve' 'Mookie Betts' 'José Abreu'
#  'Shohei Ohtani']
#                  Name  Age  #days     Lev           Tm    G   PA   AB    R  \
# 259    Dustin Pedroia   24   5062  Maj-AL       Boston  150  695  625  117
# 260    Dustin Pedroia   24   5062  Maj-AL       Boston  150  695  625  117
# 261    Dustin Pedroia   24   5062  Maj-AL       Boston  150  695  625  117
# 224         Joe Mauer   26   4691  Maj-AL    Minnesota  137  600  519   94
# 225         Joe Mauer   26   4691  Maj-AL    Minnesota  137  600  519   94
# 226         Joe Mauer   26   4691  Maj-AL    Minnesota  137  600  519   94
# 138     Josh Hamilton   29   4327  Maj-AL        Texas  132  567  515   94
# 139     Josh Hamilton   29   4327  Maj-AL        Texas  132  567  515   94
# 140     Josh Hamilton   29   4327  Maj-AL        Texas  132  567  515   94
# 141     Josh Hamilton   29   4327  Maj-AL        Texas  132  567  515   94
# 352  Justin Verlander   28   4068  Maj-AL      Detroit    1    4    4    0
# 353  Justin Verlander   28   4068  Maj-AL      Detroit    1    4    4    0
# 354  Justin Verlander   28   4068  Maj-AL      Detroit    1    4    4    0
# 355  Justin Verlander   28   4068  Maj-AL      Detroit    1    4    4    0
# 356  Justin Verlander   28   4068  Maj-AL      Detroit    1    4    4    0
# 41     Miguel Cabrera   29   3596  Maj-AL      Detroit  160  693  621  109
# 42     Miguel Cabrera   29   3596  Maj-AL      Detroit  160  693  621  109
# 43     Miguel Cabrera   29   3596  Maj-AL      Detroit  160  693  621  109
# 44     Miguel Cabrera   29   3596  Maj-AL      Detroit  160  693  621  109
# 45     Miguel Cabrera   29   3596  Maj-AL      Detroit  160  693  621  109
# 53     Miguel Cabrera   30   3236  Maj-AL      Detroit  142  628  535   98
# 54     Miguel Cabrera   30   3236  Maj-AL      Detroit  142  628  535   98
# 55     Miguel Cabrera   30   3236  Maj-AL      Detroit  142  628  535   98
# 56     Miguel Cabrera   30   3236  Maj-AL      Detroit  142  628  535   98
# 420        Mike Trout   22   2871  Maj-AL  Los Angeles  151  679  579  112
# 421        Mike Trout   22   2871  Maj-AL  Los Angeles  151  679  579  112
# 422        Mike Trout   22   2871  Maj-AL  Los Angeles  151  679  579  112
# 423        Mike Trout   22   2871  Maj-AL  Los Angeles  151  679  579  112
# 10        Jose Altuve   27   1772  Maj-AL      Houston  149  645  573  112
# 11        Jose Altuve   27   1772  Maj-AL      Houston  149  645  573  112
# 12        Jose Altuve   27   1772  Maj-AL      Houston  149  645  573  112
# 13        Jose Altuve   27   1772  Maj-AL      Houston  149  645  573  112
# 41       Mookie Betts   25   1408  Maj-AL       Boston  129  583  494  125
# 42       Mookie Betts   25   1408  Maj-AL       Boston  129  583  494  125
# 43       Mookie Betts   25   1408  Maj-AL       Boston  129  583  494  125
# 44       Mookie Betts   25   1408  Maj-AL       Boston  129  583  494  125
# 398        Mike Trout   27   1066  Maj-AL  Los Angeles  125  562  444  105
# 399        Mike Trout   27   1066  Maj-AL  Los Angeles  125  562  444  105
# 400        Mike Trout   27   1066  Maj-AL  Los Angeles  125  562  444  105
# 401        Mike Trout   27   1066  Maj-AL  Los Angeles  125  562  444  105
# 0          José Abreu   33    680  Maj-AL      Chicago   60  262  240   43
# 1          José Abreu   33    680  Maj-AL      Chicago   60  262  240   43
# 2          José Abreu   33    680  Maj-AL      Chicago   60  262  240   43
# 3          José Abreu   33    680  Maj-AL      Chicago   60  262  240   43
# 310     Shohei Ohtani   26    309  Maj-AL  Los Angeles  149  618  517   97
# 311     Shohei Ohtani   26    309  Maj-AL  Los Angeles  149  618  517   97
# 312     Shohei Ohtani   26    309  Maj-AL  Los Angeles  149  618  517   97
# 313     Shohei Ohtani   26    309  Maj-AL  Los Angeles  149  618  517   97
#
#        H  ...  SB  CS     BA    OBP    SLG    OPS  year_ID    WAR  MVP  \
# 259  206  ...  20   0  0.330  0.379  0.501  0.880   2008.0   6.95    1
# 260  206  ...  20   0  0.330  0.379  0.501  0.880   2008.0   6.95    1
# 261  206  ...  20   0  0.330  0.379  0.501  0.880   2008.0   6.95    1
# 224  189  ...   4   1  0.364  0.442  0.586  1.027   2009.0   7.83    1
# 225  189  ...   4   1  0.364  0.442  0.586  1.027   2009.0   7.83    1
# 226  189  ...   4   1  0.364  0.442  0.586  1.027   2009.0   7.83    1
# 138  186  ...   8   1  0.361  0.412  0.637  1.049   2010.0   8.71    1
# 139  186  ...   8   1  0.361  0.412  0.637  1.049   2010.0   8.71    1
# 140  186  ...   8   1  0.361  0.412  0.637  1.049   2010.0   8.71    1
# 141  186  ...   8   1  0.361  0.412  0.637  1.049   2010.0   8.71    1
# 352    0  ...   0   0  0.000  0.000  0.000  0.000   2011.0  -0.06    1
# 353    0  ...   0   0  0.000  0.000  0.000  0.000   2011.0  -0.06    1
# 354    0  ...   0   0  0.000  0.000  0.000  0.000   2011.0  -0.06    1
# 355    0  ...   0   0  0.000  0.000  0.000  0.000   2011.0  -0.06    1
# 356    0  ...   0   0  0.000  0.000  0.000  0.000   2011.0  -0.06    1
# 41   205  ...   4   1  0.330  0.391  0.607  0.998   2012.0   7.14    1
# 42   205  ...   4   1  0.330  0.391  0.607  0.998   2012.0   7.14    1
# 43   205  ...   4   1  0.330  0.391  0.607  0.998   2012.0   7.14    1
# 44   205  ...   4   1  0.330  0.391  0.607  0.998   2012.0   7.14    1
# 45   205  ...   4   1  0.330  0.391  0.607  0.998   2012.0   7.14    1
# 53   186  ...   3   0  0.348  0.441  0.645  1.086   2013.0   7.49    1
# 54   186  ...   3   0  0.348  0.441  0.645  1.086   2013.0   7.49    1
# 55   186  ...   3   0  0.348  0.441  0.645  1.086   2013.0   7.49    1
# 56   186  ...   3   0  0.348  0.441  0.645  1.086   2013.0   7.49    1
# 420  166  ...  16   2  0.287  0.377  0.556  0.933   2014.0   7.71    1
# 421  166  ...  16   2  0.287  0.377  0.556  0.933   2014.0   7.71    1
# 422  166  ...  16   2  0.287  0.377  0.556  0.933   2014.0   7.71    1
# 423  166  ...  16   2  0.287  0.377  0.556  0.933   2014.0   7.71    1
# 10   201  ...  32   5  0.351  0.416  0.559  0.975   2017.0   7.67    1
# 11   201  ...  32   5  0.351  0.416  0.559  0.975   2017.0   7.67    1
# 12   201  ...  32   5  0.351  0.416  0.559  0.975   2017.0   7.67    1
# 13   201  ...  32   5  0.351  0.416  0.559  0.975   2017.0   7.67    1
# 41   171  ...  28   5  0.346  0.437  0.648  1.085   2018.0  10.68    1
# 42   171  ...  28   5  0.346  0.437  0.648  1.085   2018.0  10.68    1
# 43   171  ...  28   5  0.346  0.437  0.648  1.085   2018.0  10.68    1
# 44   171  ...  28   5  0.346  0.437  0.648  1.085   2018.0  10.68    1
# 398  127  ...  10   0  0.286  0.431  0.628  1.059   2019.0   7.89    1
# 399  127  ...  10   0  0.286  0.431  0.628  1.059   2019.0   7.89    1
# 400  127  ...  10   0  0.286  0.431  0.628  1.059   2019.0   7.89    1
# 401  127  ...  10   0  0.286  0.431  0.628  1.059   2019.0   7.89    1
# 0     76  ...   0   0  0.317  0.370  0.617  0.987   2020.0   3.01    1
# 1     76  ...   0   0  0.317  0.370  0.617  0.987   2020.0   3.01    1
# 2     76  ...   0   0  0.317  0.370  0.617  0.987   2020.0   3.01    1
# 3     76  ...   0   0  0.317  0.370  0.617  0.987   2020.0   3.01    1
# 310  132  ...  24  10  0.255  0.374  0.588  0.962   2021.0   4.93    1
# 311  132  ...  24  10  0.255  0.374  0.588  0.962   2021.0   4.93    1
# 312  132  ...  24  10  0.255  0.374  0.588  0.962   2021.0   4.93    1
# 313  132  ...  24  10  0.255  0.374  0.588  0.962   2021.0   4.93    1
#
#                                  awardID
# 259                           Gold Glove
# 260                 Most Valuable Player
# 261                       Silver Slugger
# 224                           Gold Glove
# 225                 Most Valuable Player
# 226                       Silver Slugger
# 138                             ALCS MVP
# 139                 Most Valuable Player
# 140                       Silver Slugger
# 141  TSN Major League Player of the Year
# 352                       Cy Young Award
# 353                 Most Valuable Player
# 354                Pitching Triple Crown
# 355  TSN Major League Player of the Year
# 356              TSN Pitcher of the Year
# 41                      Hank Aaron Award
# 42                  Most Valuable Player
# 43                        Silver Slugger
# 44                          Triple Crown
# 45   TSN Major League Player of the Year
# 53                      Hank Aaron Award
# 54                  Most Valuable Player
# 55                        Silver Slugger
# 56   TSN Major League Player of the Year
# 420                    All-Star Game MVP
# 421                     Hank Aaron Award
# 422                 Most Valuable Player
# 423                       Silver Slugger
# 10                  Most Valuable Player
# 11                      Hank Aaron Award
# 12                        Silver Slugger
# 13                          TSN All-Star
# 41                  Most Valuable Player
# 42                        Silver Slugger
# 43                            Gold Glove
# 44                          TSN All-Star
# 398                 Most Valuable Player
# 399                     Hank Aaron Award
# 400                       Silver Slugger
# 401                         TSN All-Star
# 0                   Most Valuable Player
# 1                       Hank Aaron Award
# 2                         Silver Slugger
# 3                           TSN All-Star
# 310                 Most Valuable Player
# 311                       Silver Slugger
# 312                 Outstanding DH Award
# 313                         TSN All-Star
#
# [48 rows x 29 columns]

# %% [markdown]
# ## Export to Postgre
#
# Make sure this connection string work:
#
#  1) Verify connection points, and import config with variable db_password=YOUR_POSTGRE_PASSWORD
#
#  2) Creating a Raw_Teams database in Postgre
#
#  3) Drop 'AL' and 'NL' tables if they exist

# %%
engine = create_engine(f"postgresql://postgres:{db_password}@127.0.0.1:5432/Raw_Teams")

data_NL.to_sql(name='NL', con=engine)
data_AL.to_sql(name='AL', con=engine)
# Out:
# 931
