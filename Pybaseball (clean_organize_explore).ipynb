# %%
# The purose of this notebook is to clean, organize, and explore the data set 
# before determining the most important features for our machine learning model.

# %%
# Import packages and libraries

from pybaseball import batting_stats_range
from pybaseball import batting_stats
from pathlib import Path
import numpy as np
import pandas as pd

# %%
# Gathering batting stats from 2015

data = batting_stats(2015)

batting_df = pd.DataFrame(data)
batting_df.head()
# Out:
#     IDfg  Season              Name Team  Age    G   AB   PA    H   1B  ...  \
# 0  11579    2015      Bryce Harper  WSN   22  153  521  654  172   91  ...
# 3  10155    2015        Mike Trout  LAA   23  159  575  682  172   93  ...
# 5   5038    2015    Josh Donaldson  TOR   29  158  620  711  184  100  ...
# 1   4314    2015        Joey Votto  CIN   31  158  545  695  171  107  ...
# 2   9218    2015  Paul Goldschmidt  ARI   27  159  567  695  182  109  ...
#
#    Barrel%  maxEV  HardHit  HardHit%  Events  CStr%   CSW%    xBA   xSLG  \
# 0    0.122  116.0      188     0.477     394  0.118  0.226  0.292  0.544
# 3    0.161  117.7      205     0.486     422  0.207  0.282  0.297  0.588
# 5    0.114  113.6      232     0.465     499  0.145  0.255  0.280  0.546
# 1    0.095  109.3      175     0.425     412  0.177  0.254  0.289  0.541
# 2    0.123  114.0      197     0.465     424  0.181  0.266  0.279  0.558
#
#    xwOBA
# 0  0.418
# 3  0.422
# 5  0.390
# 1  0.422
# 2  0.403
#
# ...

# %%
len(data)
# Out:
# 141

# %%
# Dropped all columns with NaN values 

batting_df = batting_df.dropna(axis=1)
batting_df
# Out:
#       IDfg  Season              Name Team  Age    G   AB   PA    H   1B  ...  \
# 0    11579    2015      Bryce Harper  WSN   22  153  521  654  172   91  ...
# 3    10155    2015        Mike Trout  LAA   23  159  575  682  172   93  ...
# 5     5038    2015    Josh Donaldson  TOR   29  158  620  711  184  100  ...
# 1     4314    2015        Joey Votto  CIN   31  158  545  695  171  107  ...
# 2     9218    2015  Paul Goldschmidt  ARI   27  159  567  695  182  109  ...
# ..     ...     ...               ...  ...  ...  ...  ...  ...  ...  ...  ...
# 123   5760    2015    Avisail Garcia  CHW   24  148  553  601  142  110  ...
# 139   1433    2015      Wilson Ramos  WSN   27  128  475  504  109   78  ...
# 97    7399    2015      Billy Butler  OAK   29  151  538  601  135   91  ...
# 140  10030    2015      Chris Owings  ARI   23  147  515  552  117   81  ...
# 128   5409    2015    Pablo Sandoval  BOS   28  126  470  505  115   79  ...
#
# ...

# %%
batting_df = batting_df.drop(columns= ['IDfg','Season','Team','Age'])
batting_df
# Out:
#                  Name    G   AB   PA    H   1B  2B  3B  HR    R  ...  Barrel%  \
# 0        Bryce Harper  153  521  654  172   91  38   1  42  118  ...    0.122
# 3          Mike Trout  159  575  682  172   93  32   6  41  104  ...    0.161
# 5      Josh Donaldson  158  620  711  184  100  41   2  41  122  ...    0.114
# 1          Joey Votto  158  545  695  171  107  33   2  29   95  ...    0.095
# 2    Paul Goldschmidt  159  567  695  182  109  38   2  33  103  ...    0.123
# ..                ...  ...  ...  ...  ...  ...  ..  ..  ..  ...  ...      ...
# 123    Avisail Garcia  148  553  601  142  110  17   2  13   66  ...    0.043
# 139      Wilson Ramos  128  475  504  109   78  16   0  15   41  ...    0.058
# 97       Billy Butler  151  538  601  135   91  28   1  15   63  ...    0.070
# 140      Chris Owings  147  515  552  117   81  27   5   4   59  ...    0.026
# 128    Pablo Sandoval  126  470  505  115   79  25   1  10   43  ...    0.045
#
# ...

# %%
batting_df.describe()
# Out:
#                 G          AB          PA           H          1B          2B  \
# count  141.000000  141.000000  141.000000  141.000000  141.000000  141.000000
# mean   147.397163  545.234043  605.929078  148.631206   97.943262   29.092199
# std     10.181832   52.314111   60.458090   22.256752   21.314909    6.905382
# min    116.000000  429.000000  503.000000  101.000000   54.000000   14.000000
# 25%    141.000000  505.000000  553.000000  133.000000   81.000000   24.000000
# 50%    151.000000  549.000000  612.000000  147.000000   98.000000   29.000000
# 75%    156.000000  586.000000  657.000000  165.000000  111.000000   34.000000
# max    162.000000  638.000000  713.000000  205.000000  169.000000   45.000000
#
#                3B          HR           R         RBI  ...     Barrel%  \
# count  141.000000  141.000000  141.000000  141.000000  ...  141.000000
# mean     3.106383   18.489362   74.297872   71.439716  ...    0.055532
# ...

# %%
# Adding a 'MVP' column

batting_df["MVP"] = "np.NaT"
batting_df
# Out:
#                  Name    G   AB   PA    H   1B  2B  3B  HR    R  ...  maxEV  \
# 0        Bryce Harper  153  521  654  172   91  38   1  42  118  ...  116.0
# 3          Mike Trout  159  575  682  172   93  32   6  41  104  ...  117.7
# 5      Josh Donaldson  158  620  711  184  100  41   2  41  122  ...  113.6
# 1          Joey Votto  158  545  695  171  107  33   2  29   95  ...  109.3
# 2    Paul Goldschmidt  159  567  695  182  109  38   2  33  103  ...  114.0
# ..                ...  ...  ...  ...  ...  ...  ..  ..  ..  ...  ...    ...
# 123    Avisail Garcia  148  553  601  142  110  17   2  13   66  ...  116.1
# 139      Wilson Ramos  128  475  504  109   78  16   0  15   41  ...  114.2
# 97       Billy Butler  151  538  601  135   91  28   1  15   63  ...  110.0
# 140      Chris Owings  147  515  552  117   81  27   5   4   59  ...  107.6
# 128    Pablo Sandoval  126  470  505  115   79  25   1  10   43  ...  114.0
#
# ...

# %%
# Changing the values in the 'MVP' column to '0'.

batting_df['MVP'] = 0
batting_df.head()
# Out:
#                Name    G   AB   PA    H   1B  2B  3B  HR    R  ...  maxEV  \
# 0      Bryce Harper  153  521  654  172   91  38   1  42  118  ...  116.0
# 3        Mike Trout  159  575  682  172   93  32   6  41  104  ...  117.7
# 5    Josh Donaldson  158  620  711  184  100  41   2  41  122  ...  113.6
# 1        Joey Votto  158  545  695  171  107  33   2  29   95  ...  109.3
# 2  Paul Goldschmidt  159  567  695  182  109  38   2  33  103  ...  114.0
#
#    HardHit  HardHit%  Events  CStr%   CSW%    xBA   xSLG  xwOBA  MVP
# 0      188     0.477     394  0.118  0.226  0.292  0.544  0.418    0
# 3      205     0.486     422  0.207  0.282  0.297  0.588  0.422    0
# 5      232     0.465     499  0.145  0.255  0.280  0.546  0.390    0
# 1      175     0.425     412  0.177  0.254  0.289  0.541  0.422    0
# 2      197     0.465     424  0.181  0.266  0.279  0.558  0.403    0
#
# [5 rows x 259 columns]

# %%
# This dataset is for the year 2015. Josh Donaldson won MVP that year - assigning a '1' to his 'MVP' column.

batting_df.at[5, 'MVP']=1
batting_df.head()
# Out:
#                Name    G   AB   PA    H   1B  2B  3B  HR    R  ...  maxEV  \
# 0      Bryce Harper  153  521  654  172   91  38   1  42  118  ...  116.0
# 3        Mike Trout  159  575  682  172   93  32   6  41  104  ...  117.7
# 5    Josh Donaldson  158  620  711  184  100  41   2  41  122  ...  113.6
# 1        Joey Votto  158  545  695  171  107  33   2  29   95  ...  109.3
# 2  Paul Goldschmidt  159  567  695  182  109  38   2  33  103  ...  114.0
#
#    HardHit  HardHit%  Events  CStr%   CSW%    xBA   xSLG  xwOBA  MVP
# 0      188     0.477     394  0.118  0.226  0.292  0.544  0.418    0
# 3      205     0.486     422  0.207  0.282  0.297  0.588  0.422    0
# 5      232     0.465     499  0.145  0.255  0.280  0.546  0.390    1
# 1      175     0.425     412  0.177  0.254  0.289  0.541  0.422    0
# 2      197     0.465     424  0.181  0.266  0.279  0.558  0.403    0
#
# [5 rows x 259 columns]

# %%
list(batting_df.columns)
# Out:
# ['Name',
#  'G',
#  'AB',
#  'PA',
#  'H',
#  '1B',
#  '2B',
#  '3B',
#  'HR',
#  'R',
#  'RBI',
#  'BB',
#  'IBB',
#  'SO',
#  'HBP',
#  'SF',
#  'SH',
#  'GDP',
#  'SB',
#  'CS',
#  'AVG',
#  'GB',
#  'FB',
#  'LD',
#  'IFFB',
#  'Pitches',
#  'Balls',
#  'Strikes',
#  'IFH',
#  'BU',
#  'BUH',
#  'BB%',
#  'K%',
#  'BB/K',
#  'OBP',
#  'SLG',
#  'OPS',
#  'ISO',
#  'BABIP',
#  'GB/FB',
#  'LD%',
#  'GB%',
#  'FB%',
#  'IFFB%',
#  'HR/FB',
#  'IFH%',
#  'BUH%',
#  'wOBA',
#  'wRAA',
#  'wRC',
#  'Bat',
#  'Fld',
#  'Rep',
#  'Pos',
#  'RAR',
#  'WAR',
#  'Dol',
#  'Spd',
#  'wRC+',
#  'WPA',
#  '-WPA',
#  '+WPA',
#  'RE24',
#  'REW',
#  'pLI',
#  'PH',
#  'WPA/LI',
#  'Clutch',
#  'FB% (Pitch)',
#  'FBv',
#  'SL%',
#  'SLv',
#  'CT%',
#  'CTv',
#  'CB%',
#  'CBv',
#  'CH%',
#  'CHv',
#  'SF%',
#  'SFv',
#  'wFB',
#  'wSL',
#  'wCT',
#  'wCB',
#  'wCH',
#  'wSF',
#  'wFB/C',
#  'wSL/C',
#  'wCT/C',
#  'wCB/C',
#  'wCH/C',
#  'wSF/C',
#  'O-Swing%',
#  'Z-Swing%',
#  'Swing%',
# ...

# %%
batting_df = batting_df[['Name',
 'G',
 'AB',
 'PA',
 'H',
 '1B',
 '2B',
 '3B',
 'HR',
 'R',
 'RBI',
 'BB',
 'IBB',
 'SO',
 'HBP',
 'SF',
 'SH',
 'GDP',
 'SB',
 'CS',
 'AVG',
 'GB',
 'FB',
 'LD',
 'IFFB',
 'Pitches',
 'Balls',
 'Strikes',
 'IFH',
 'BU',
 'BUH',
 'BB%',
 'K%',
 'BB/K',
 'OBP',
 'SLG',
 'OPS',
 'ISO',
 'BABIP',
 'GB/FB',
 'LD%',
 'GB%',
 'FB%',
 'IFFB%',
 'HR/FB',
 'IFH%',
 'BUH%',
 'wOBA',
 'wRAA',
 'wRC',
 'Bat',
 'Fld',
 'Rep',
 'Pos',
 'RAR',
 'WAR',
 'MVP']]

batting_df.head()
# Out:
#                Name    G   AB   PA    H   1B  2B  3B  HR    R  ...   wOBA  \
# 0      Bryce Harper  153  521  654  172   91  38   1  42  118  ...  0.461
# 3        Mike Trout  159  575  682  172   93  32   6  41  104  ...  0.415
# 5    Josh Donaldson  158  620  711  184  100  41   2  41  122  ...  0.398
# 1        Joey Votto  158  545  695  171  107  33   2  29   95  ...  0.427
# 2  Paul Goldschmidt  159  567  695  182  109  38   2  33  103  ...  0.418
#
#    wRAA  wRC   Bat  Fld   Rep   Pos   RAR  WAR  MVP
# 0  77.3  151  74.1 -4.0  19.1  -6.1  87.8  9.3    0
# 3  55.4  132  55.7  4.7  19.9   1.9  87.6  9.3    0
# 5  47.9  128  44.7  8.6  20.8   1.5  82.1  8.7    1
# 1  63.1  141  59.8  0.0  20.3 -11.8  68.3  7.3    0
# 2  57.9  136  51.1  4.6  20.3 -12.1  68.1  7.2    0
#
# [5 rows x 57 columns]

# %%
list(batting_df.dtypes)
# Out:
# [dtype('O'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('float64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('int64'),
# ...

# %%
# Converting batting_df into a CSV and saving to branch/repository 

batting_df.to_csv('batting_df.csv')
