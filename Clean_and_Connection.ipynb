# %%
from Cleaner import *
from config import db_password

# %% [markdown]
# ## Create the DataFrame

# %% [markdown]
# ### Player Awards
# Up-To-Date data from [Sean Lahman](https://www.seanlahman.com/baseball-archive/statistics/)

# %%
awards = pd.read_csv('Resources/AwardsPlayers.csv')
all_awards = reverseLookup(awards)
# Out:
# Gathering player lookup table. This may take a moment.

# %% [markdown]
# ### Merge awards and players dataframes

# %%
data_NL, data_AL = Merger(all_awards)
data_NL
# Out:
# ............Scraping Data.............
#
# 1982 Time: 1.048821210861206 Seconds
# 1983 Time: 1.0284976959228516 Seconds
# 1984 Time: 0.9656410217285156 Seconds
# 1985 Time: 1.040351152420044 Seconds
# 1986 Time: 0.962033748626709 Seconds
#
# .....Approximately 39-49 Seconds.....
#
# Total Time: 43.75158095359802 Seconds
#         IDfg  Season              Name Team  Age    G   AB   PA    H   1B  \
# 6    1002015    1982       Gary Carter  MON   28  154  557  653  163  101
# 7    1002015    1982       Gary Carter  MON   28  154  557  653  163  101
# 8    1002015    1982       Gary Carter  MON   28  154  557  653  163  101
# 9    1003091    1982      Andre Dawson  MON   27  148  607  659  183  116
# 12   1011586    1982      Mike Schmidt  PHI   32  148  514  631  144   80
# ..       ...     ...               ...  ...  ...  ...  ...  ...  ...  ...
# 139     3516    2021       Eric Hosmer  SDP   31  151  509  565  137   97
# 141     7859    2021  Charlie Blackmon  COL   34  150  514  582  139   97
# 142    19892    2021       Pavin Smith  ARI   25  145  498  545  133   91
# 143    12552    2021    Eugenio Suarez  CIN   29  145  505  574  100   46
# 145    17696    2021      Kevin Newman  PIT   27  148  517  554  117   87
#
#      ...   CSW%    xBA   xSLG  xwOBA  key_fangraphs   playerID  \
# 6    ...    NaN    NaN    NaN    NaN      1002015.0  cartega01
# 7    ...    NaN    NaN    NaN    NaN      1002015.0  cartega01
# 8    ...    NaN    NaN    NaN    NaN      1002015.0  cartega01
# 9    ...    NaN    NaN    NaN    NaN      1003091.0  dawsoan01
# 12   ...    NaN    NaN    NaN    NaN      1011586.0  schmimi01
# ..   ...    ...    ...    ...    ...            ...        ...
# 139  ...  0.263  0.268  0.406  0.326            NaN        NaN
# 141  ...  0.250  0.291  0.450  0.359            NaN        NaN
# 142  ...  0.282  0.258  0.402  0.317            NaN        NaN
# 143  ...  0.295  0.215  0.455  0.326            NaN        NaN
# 145  ...  0.255  0.255  0.330  0.275            NaN        NaN
#
#             awardID  yearID  lgID  MVP
# 6        Gold Glove  1982.0    NL    0
# 7    Silver Slugger  1982.0    NL    0
# 8      TSN All-Star  1982.0    NL    0
# 9        Gold Glove  1982.0    NL    0
# 12       Gold Glove  1982.0    NL    0
# ..              ...     ...   ...  ...
# 139        No Award     NaN    NL    0
# 141        No Award     NaN    NL    0
# 142        No Award     NaN    NL    0
# 143        No Award     NaN    NL    0
# 145        No Award     NaN    NL    0
#
# [2883 rows x 325 columns]

# %% [markdown]
# ### National League Check

# %%
new = all_awards.loc[(all_awards['awardID']=='Most Valuable Player') &
              (all_awards['lgID']=='NL')].sort_values(by = ['yearID']).tail(40)
print(new['Name'].nunique())
new['Name'].unique()
# Out:
# 30
# array(['Dale Murphy', 'Ryne Sandberg', 'Willie Mcgee', 'Mike Schmidt',
#        'Andre Dawson', 'Kirk Gibson', 'Kevin Mitchell', 'Barry Bonds',
#        'Terry Pendleton', 'Jeff Bagwell', 'Barry Larkin', 'Ken Caminiti',
#        'Larry Walker', 'Sammy Sosa', 'Chipper Jones', 'Jeff Kent',
#        'Albert Pujols', 'Ryan Howard', 'Jimmy Rollins', 'Joey Votto',
#        'Ryan Braun', 'Buster Posey', 'Andrew Mccutchen',
#        'Clayton Kershaw', 'Bryce Harper', 'Kris Bryant',
#        'Giancarlo Stanton', 'Christian Yelich', 'Cody Bellinger',
#        'Freddie Freeman'], dtype=object)

# %%
mvpVerify(data_NL).head(20)
# Out:
# There are/is 28 unique mvps over 38 Seasons
# ['Dale Murphy' 'Ryne Sandberg' 'Willie McGee' 'Mike Schmidt'
#  'Andre Dawson' 'Kirk Gibson' 'Kevin Mitchell' 'Barry Bonds'
#  'Terry Pendleton' 'Jeff Bagwell' 'Barry Larkin' 'Ken Caminiti'
#  'Larry Walker' 'Sammy Sosa' 'Chipper Jones' 'Jeff Kent' 'Albert Pujols'
#  'Ryan Howard' 'Jimmy Rollins' 'Joey Votto' 'Ryan Braun' 'Buster Posey'
#  'Andrew McCutchen' 'Bryce Harper' 'Kris Bryant' 'Giancarlo Stanton'
#  'Christian Yelich' 'Cody Bellinger']
#        IDfg  Season           Name Team  Age    G   AB   PA    H   1B  ...  \
# 19  1009355    1982    Dale Murphy  ATL   26  162  598  698  168  107  ...
# 20  1009355    1982    Dale Murphy  ATL   26  162  598  698  168  107  ...
# 21  1009355    1982    Dale Murphy  ATL   26  162  598  698  168  107  ...
# 22  1009355    1982    Dale Murphy  ATL   26  162  598  698  168  107  ...
# 23  1009355    1982    Dale Murphy  ATL   26  162  598  698  168  107  ...
# 9   1009355    1983    Dale Murphy  ATL   27  162  589  687  178  114  ...
# 10  1009355    1983    Dale Murphy  ATL   27  162  589  687  178  114  ...
# 11  1009355    1983    Dale Murphy  ATL   27  162  589  687  178  114  ...
# 12  1009355    1983    Dale Murphy  ATL   27  162  589  687  178  114  ...
# 13  1009355    1983    Dale Murphy  ATL   27  162  589  687  178  114  ...
# 2   1011411    1984  Ryne Sandberg  CHC   24  156  636  700  200  126  ...
# 3   1011411    1984  Ryne Sandberg  CHC   24  156  636  700  200  126  ...
# 4   1011411    1984  Ryne Sandberg  CHC   24  156  636  700  200  126  ...
# 5   1011411    1984  Ryne Sandberg  CHC   24  156  636  700  200  126  ...
# 6   1011411    1984  Ryne Sandberg  CHC   24  156  636  700  200  126  ...
# 7   1011411    1984  Ryne Sandberg  CHC   24  156  636  700  200  126  ...
# 8   1008513    1985   Willie McGee  STL   26  152  612  652  216  162  ...
# 9   1008513    1985   Willie McGee  STL   26  152  612  652  216  162  ...
# 10  1008513    1985   Willie McGee  STL   26  152  612  652  216  162  ...
# 11  1008513    1985   Willie McGee  STL   26  152  612  652  216  162  ...
#
#     CSW%  xBA  xSLG  xwOBA  key_fangraphs   playerID  \
# 19   NaN  NaN   NaN    NaN      1009355.0  murphda05
# 20   NaN  NaN   NaN    NaN      1009355.0  murphda05
# 21   NaN  NaN   NaN    NaN      1009355.0  murphda05
# 22   NaN  NaN   NaN    NaN      1009355.0  murphda05
# 23   NaN  NaN   NaN    NaN      1009355.0  murphda05
# 9    NaN  NaN   NaN    NaN      1009355.0  murphda05
# 10   NaN  NaN   NaN    NaN      1009355.0  murphda05
# 11   NaN  NaN   NaN    NaN      1009355.0  murphda05
# 12   NaN  NaN   NaN    NaN      1009355.0  murphda05
# 13   NaN  NaN   NaN    NaN      1009355.0  murphda05
# 2    NaN  NaN   NaN    NaN      1011411.0  sandbry01
# 3    NaN  NaN   NaN    NaN      1011411.0  sandbry01
# 4    NaN  NaN   NaN    NaN      1011411.0  sandbry01
# 5    NaN  NaN   NaN    NaN      1011411.0  sandbry01
# 6    NaN  NaN   NaN    NaN      1011411.0  sandbry01
# 7    NaN  NaN   NaN    NaN      1011411.0  sandbry01
# 8    NaN  NaN   NaN    NaN      1008513.0  mcgeewi01
# 9    NaN  NaN   NaN    NaN      1008513.0  mcgeewi01
# 10   NaN  NaN   NaN    NaN      1008513.0  mcgeewi01
# 11   NaN  NaN   NaN    NaN      1008513.0  mcgeewi01
#
#                                 awardID  yearID  lgID  MVP
# 19                           Gold Glove  1982.0    NL    1
# 20                 Most Valuable Player  1982.0    NL    1
# 21                       Silver Slugger  1982.0    NL    1
# 22                         TSN All-Star  1982.0    NL    1
# 23               TSN Player of the Year  1982.0    NL    1
# 9                            Gold Glove  1983.0    NL    1
# 10                 Most Valuable Player  1983.0    NL    1
# 11                       Silver Slugger  1983.0    NL    1
# 12                         TSN All-Star  1983.0    NL    1
# 13               TSN Player of the Year  1983.0    NL    1
# 2                            Gold Glove  1984.0    NL    1
# 3                  Most Valuable Player  1984.0    NL    1
# 4                        Silver Slugger  1984.0    NL    1
# 5                          TSN All-Star  1984.0    NL    1
# 6   TSN Major League Player of the Year  1984.0    NL    1
# 7                TSN Player of the Year  1984.0    NL    1
# 8                            Gold Glove  1985.0    NL    1
# 9                  Most Valuable Player  1985.0    NL    1
# 10                       Silver Slugger  1985.0    NL    1
# 11                         TSN All-Star  1985.0    NL    1
#
# [20 rows x 325 columns]

# %% [markdown]
# ### American League Check

# %%
new = all_awards.loc[(all_awards['awardID']=='Most Valuable Player') &
              (all_awards['lgID']=='AL')].sort_values(by = ['yearID']).tail(40)
print(new['Name'].nunique())
new['Name'].unique()
# Out:
# 31
# array(['Robin Yount', 'Cal Ripken', 'Willie Hernandez', 'Don Mattingly',
#        'Roger Clemens', 'George Bell', 'Jose Canseco', 'Rickey Henderson',
#        'Dennis Eckersley', 'Frank Thomas', 'Mo Vaughn', 'Juan Gonzalez',
#        'Ken Griffey', 'Ivan Rodriguez', 'Jason Giambi', 'Ichiro Suzuki',
#        'Miguel Tejada', 'Alex Rodriguez', 'Vladimir Guerrero',
#        'Justin Morneau', 'Dustin Pedroia', 'Joe Mauer', 'Josh Hamilton',
#        'Justin Verlander', 'Miguel Cabrera', 'Mike Trout',
#        'Josh Donaldson', 'Jose Altuve', 'Mookie Betts', 'José Abreu',
#        'Shohei Ohtani'], dtype=object)

# %%
mvpVerify(data_AL).head(13)
# Out:
# There are/is 26 unique mvps over 35 Seasons
# ['Robin Yount' 'Cal Ripken' 'Don Mattingly' 'George Bell' 'Jose Canseco'
#  'Rickey Henderson' 'Frank Thomas' 'Mo Vaughn' 'Juan Gonzalez'
#  'Ken Griffey Jr.' 'Ivan Rodriguez' 'Jason Giambi' 'Ichiro Suzuki'
#  'Miguel Tejada' 'Alex Rodriguez' 'Vladimir Guerrero' 'Justin Morneau'
#  'Dustin Pedroia' 'Joe Mauer' 'Josh Hamilton' 'Miguel Cabrera'
#  'Mike Trout' 'Josh Donaldson' 'Jose Altuve' 'Mookie Betts'
#  'Shohei Ohtani']
#        IDfg  Season           Name Team  Age    G   AB   PA    H   1B  ...  \
# 0   1014396    1982    Robin Yount  MIL   26  156  635  704  210  123  ...
# 1   1014396    1982    Robin Yount  MIL   26  156  635  704  210  123  ...
# 2   1014396    1982    Robin Yount  MIL   26  156  635  704  210  123  ...
# 3   1014396    1982    Robin Yount  MIL   26  156  635  704  210  123  ...
# 4   1014396    1982    Robin Yount  MIL   26  156  635  704  210  123  ...
# 5   1014396    1982    Robin Yount  MIL   26  156  635  704  210  123  ...
# 0   1010978    1983     Cal Ripken  BAL   22  162  663  726  211  135  ...
# 1   1010978    1983     Cal Ripken  BAL   22  162  663  726  211  135  ...
# 2   1010978    1983     Cal Ripken  BAL   22  162  663  726  211  135  ...
# 3   1010978    1983     Cal Ripken  BAL   22  162  663  726  211  135  ...
# 4   1010978    1983     Cal Ripken  BAL   22  162  663  726  211  135  ...
# 16  1008261    1985  Don Mattingly  NYY   24  159  652  727  211  125  ...
# 17  1008261    1985  Don Mattingly  NYY   24  159  652  727  211  125  ...
#
#     CSW%  xBA  xSLG  xwOBA  key_fangraphs   playerID  \
# 0    NaN  NaN   NaN    NaN      1014396.0  yountro01
# 1    NaN  NaN   NaN    NaN      1014396.0  yountro01
# 2    NaN  NaN   NaN    NaN      1014396.0  yountro01
# 3    NaN  NaN   NaN    NaN      1014396.0  yountro01
# 4    NaN  NaN   NaN    NaN      1014396.0  yountro01
# 5    NaN  NaN   NaN    NaN      1014396.0  yountro01
# 0    NaN  NaN   NaN    NaN      1010978.0  ripkeca01
# 1    NaN  NaN   NaN    NaN      1010978.0  ripkeca01
# 2    NaN  NaN   NaN    NaN      1010978.0  ripkeca01
# 3    NaN  NaN   NaN    NaN      1010978.0  ripkeca01
# 4    NaN  NaN   NaN    NaN      1010978.0  ripkeca01
# 16   NaN  NaN   NaN    NaN      1008261.0  mattido01
# 17   NaN  NaN   NaN    NaN      1008261.0  mattido01
#
#                                 awardID  yearID  lgID  MVP
# 0                            Gold Glove  1982.0    AL    1
# 1                  Most Valuable Player  1982.0    AL    1
# 2                        Silver Slugger  1982.0    AL    1
# 3                          TSN All-Star  1982.0    AL    1
# 4   TSN Major League Player of the Year  1982.0    AL    1
# 5                TSN Player of the Year  1982.0    AL    1
# 0                  Most Valuable Player  1983.0    AL    1
# 1                        Silver Slugger  1983.0    AL    1
# 2                          TSN All-Star  1983.0    AL    1
# 3   TSN Major League Player of the Year  1983.0    AL    1
# 4                TSN Player of the Year  1983.0    AL    1
# 16                           Gold Glove  1985.0    AL    1
# 17                 Most Valuable Player  1985.0    AL    1
#
# [13 rows x 325 columns]

# %% [markdown]
# ## Export to Postgre
#
# Make sure this connection string work:
#
#  1) Verify connection points, and import config with variable db_password=YOUR_POSTGRE_PASSWORD
#
#  2) Creating a Raw_Stats database in Postgre
#
#  3) Drop 'AL' and 'NL' tables if they exist

# %%
engine = create_engine(f"postgresql://postgres:{db_password}@127.0.0.1:5432/Raw_Stats")

data_NL.to_sql(name='NL', con=engine)
data_AL.to_sql(name='AL', con=engine)
# Out:
# 786
