# %%
from Cleaner import *
from config import db_password

# %% [markdown]
# ## Create the DataFrame

# %% [markdown]
# ### Player Awards
# Up-To-Date data from [Sean Lahman](https://www.seanlahman.com/baseball-archive/statistics/)

# %%
awards = pd.read_csv('Resources/AwardsPlayers.csv').drop(columns=['tie','notes'])
all_awards = reverseLookup(awards)
# Out:
# Gathering player lookup table. This may take a moment.

# %% [markdown]
# ### Merge awards and players dataframes

# %%
data_NL, data_AL = Merger(all_awards)
data_NL
# Out:
# ............Scraping Data.............
#
# 1982 Time: 1.976637840270996 Seconds
# 1983 Time: 1.8624529838562012 Seconds
# 1984 Time: 1.6975181102752686 Seconds
# 1985 Time: 1.801002025604248 Seconds
# 1986 Time: 1.8019063472747803 Seconds
#
# .....Approximately 76-96 Seconds.....
#
# Total Time: 82.34192657470703 Seconds
#         IDfg  Season              Name Team  Age    G   AB   PA    H   1B  \
# 6    1002015    1982       Gary Carter  MON   28  154  557  653  163  101
# 7    1002015    1982       Gary Carter  MON   28  154  557  653  163  101
# 8    1002015    1982       Gary Carter  MON   28  154  557  653  163  101
# 9    1003091    1982      Andre Dawson  MON   27  148  607  659  183  116
# 11   1011586    1982      Mike Schmidt  PHI   32  148  514  631  144   80
# ..       ...     ...               ...  ...  ...  ...  ...  ...  ...  ...
# 135     3516    2021       Eric Hosmer  SDP   31  151  509  565  137   97
# ...

# %% [markdown]
# ### National League Check

# %%
new = all_awards.loc[(all_awards['awardID']=='Most Valuable Player') &
              (all_awards['lgID']=='NL')].sort_values(by = ['yearID']).tail(40)
print(new['Name'].nunique())
new['Name'].unique()
# Out:
# 30
# array(['Dale Murphy', 'Ryne Sandberg', 'Willie Mcgee', 'Mike Schmidt',
#        'Andre Dawson', 'Kirk Gibson', 'Kevin Mitchell', 'Barry Bonds',
#        'Terry Pendleton', 'Jeff Bagwell', 'Barry Larkin', 'Ken Caminiti',
#        'Larry Walker', 'Sammy Sosa', 'Chipper Jones', 'Jeff Kent',
#        'Albert Pujols', 'Ryan Howard', 'Jimmy Rollins', 'Joey Votto',
#        'Ryan Braun', 'Buster Posey', 'Andrew Mccutchen',
#        'Clayton Kershaw', 'Bryce Harper', 'Kris Bryant',
#        'Giancarlo Stanton', 'Christian Yelich', 'Cody Bellinger',
#        'Freddie Freeman'], dtype=object)

# %%
mvpVerify(data_NL).head(13)
# Out:
# There are/is 26 unique mvps over 36 Seasons
# ['Dale Murphy' 'Ryne Sandberg' 'Mike Schmidt' 'Andre Dawson' 'Kirk Gibson'
#  'Kevin Mitchell' 'Barry Bonds' 'Terry Pendleton' 'Jeff Bagwell'
#  'Barry Larkin' 'Ken Caminiti' 'Larry Walker' 'Sammy Sosa' 'Chipper Jones'
#  'Jeff Kent' 'Albert Pujols' 'Ryan Howard' 'Jimmy Rollins' 'Joey Votto'
#  'Ryan Braun' 'Buster Posey' 'Bryce Harper' 'Kris Bryant'
#  'Giancarlo Stanton' 'Christian Yelich' 'Cody Bellinger']
#        IDfg  Season           Name Team  Age    G   AB   PA    H   1B  ...  \
# 18  1009355    1982    Dale Murphy  ATL   26  162  598  698  168  107  ...
# 19  1009355    1982    Dale Murphy  ATL   26  162  598  698  168  107  ...
# 20  1009355    1982    Dale Murphy  ATL   26  162  598  698  168  107  ...
# 21  1009355    1982    Dale Murphy  ATL   26  162  598  698  168  107  ...
# 22  1009355    1982    Dale Murphy  ATL   26  162  598  698  168  107  ...
# ...

# %% [markdown]
# ### American League Check

# %%
new = all_awards.loc[(all_awards['awardID']=='Most Valuable Player') &
              (all_awards['lgID']=='AL')].sort_values(by = ['yearID']).tail(40)
print(new['Name'].nunique())
new['Name'].unique()
# Out:
# 31
# array(['Robin Yount', 'Cal Ripken', 'Willie Hernandez', 'Don Mattingly',
#        'Roger Clemens', 'George Bell', 'Jose Canseco', 'Rickey Henderson',
#        'Dennis Eckersley', 'Frank Thomas', 'Mo Vaughn', 'Juan Gonzalez',
#        'Ken Griffey', 'Ivan Rodriguez', 'Jason Giambi', 'Ichiro Suzuki',
#        'Miguel Tejada', 'Alex Rodriguez', 'Vladimir Guerrero',
#        'Justin Morneau', 'Dustin Pedroia', 'Joe Mauer', 'Josh Hamilton',
#        'Justin Verlander', 'Miguel Cabrera', 'Mike Trout',
#        'Josh Donaldson', 'Jose Altuve', 'Mookie Betts', 'José Abreu',
#        'Shohei Ohtani'], dtype=object)

# %%
mvpVerify(data_AL).head(13)
# Out:
# There are/is 25 unique mvps over 34 Seasons
# ['Robin Yount' 'Cal Ripken' 'Don Mattingly' 'George Bell' 'Jose Canseco'
#  'Rickey Henderson' 'Frank Thomas' 'Mo Vaughn' 'Juan Gonzalez'
#  'Ivan Rodriguez' 'Jason Giambi' 'Ichiro Suzuki' 'Miguel Tejada'
#  'Alex Rodriguez' 'Vladimir Guerrero' 'Justin Morneau' 'Dustin Pedroia'
#  'Joe Mauer' 'Josh Hamilton' 'Miguel Cabrera' 'Mike Trout'
#  'Josh Donaldson' 'Jose Altuve' 'Mookie Betts' 'Shohei Ohtani']
#        IDfg  Season           Name Team  Age    G   AB   PA    H   1B  ...  \
# 0   1014396    1982    Robin Yount  MIL   26  156  635  704  210  123  ...
# 1   1014396    1982    Robin Yount  MIL   26  156  635  704  210  123  ...
# 2   1014396    1982    Robin Yount  MIL   26  156  635  704  210  123  ...
# 3   1014396    1982    Robin Yount  MIL   26  156  635  704  210  123  ...
# 4   1014396    1982    Robin Yount  MIL   26  156  635  704  210  123  ...
# 5   1014396    1982    Robin Yount  MIL   26  156  635  704  210  123  ...
# ...

# %%
data_AL.to_csv('data_AL.csv')
data_NL.to_csv('data_NL.csv')

# %%
data_AL.reset_index(drop=True, inplace=True)

# %%
data_NL.reset_index(drop=True, inplace=True)

# %%
data_AL['XBH+'] = (((data_AL['R'] + data_AL['2B'] + data_AL['3B'] + data_AL['HR']) - (data_AL['SO']))/data_AL['PA'])
data_AL.head()
# Out:
#       IDfg  Season         Name Team  Age    G   AB   PA    H   1B  ...  xSLG  \
# 0  1014396    1982  Robin Yount  MIL   26  156  635  704  210  123  ...   NaN
# 1  1014396    1982  Robin Yount  MIL   26  156  635  704  210  123  ...   NaN
# 2  1014396    1982  Robin Yount  MIL   26  156  635  704  210  123  ...   NaN
# 3  1014396    1982  Robin Yount  MIL   26  156  635  704  210  123  ...   NaN
# 4  1014396    1982  Robin Yount  MIL   26  156  635  704  210  123  ...   NaN
#
#    xwOBA  mlb_played_first  mlb_played_last   playerID  \
# 0    NaN            1974.0           1993.0  yountro01
# 1    NaN            1974.0           1993.0  yountro01
# 2    NaN            1974.0           1993.0  yountro01
# 3    NaN            1974.0           1993.0  yountro01
# 4    NaN            1974.0           1993.0  yountro01
#
#                                awardID  yearID  lgID  MVP     XBH+
# 0                           Gold Glove  1982.0    AL    1  0.21733
# ...

# %%
data_NL['XBH+'] = (((data_NL['R'] + data_NL['2B'] + data_NL['3B'] + data_NL['HR']) - (data_NL['SO']))/data_NL['PA'])
data_NL.head()
# Out:
#       IDfg  Season          Name Team  Age    G   AB   PA    H   1B  ...  \
# 0  1002015    1982   Gary Carter  MON   28  154  557  653  163  101  ...
# 1  1002015    1982   Gary Carter  MON   28  154  557  653  163  101  ...
# 2  1002015    1982   Gary Carter  MON   28  154  557  653  163  101  ...
# 3  1003091    1982  Andre Dawson  MON   27  148  607  659  183  116  ...
# 4  1011586    1982  Mike Schmidt  PHI   32  148  514  631  144   80  ...
#
#    xSLG  xwOBA  mlb_played_first  mlb_played_last   playerID         awardID  \
# 0   NaN    NaN            1974.0           1992.0  cartega01      Gold Glove
# 1   NaN    NaN            1974.0           1992.0  cartega01  Silver Slugger
# 2   NaN    NaN            1974.0           1992.0  cartega01    TSN All-Star
# 3   NaN    NaN            1976.0           1996.0  dawsoan01      Gold Glove
# 4   NaN    NaN            1972.0           1989.0  schmimi01      Gold Glove
#
#    yearID  lgID  MVP      XBH+
# 0  1982.0    NL    0  0.136294
# ...

# %% [markdown]
# ## Export to Postgre
#
# Make sure this connection string work:
#
#  1) Verify connection points, and import config with variable db_password=YOUR_POSTGRE_PASSWORD
#
#  2) Creating a Raw_Stats database in Postgre
#
#  3) Drop 'AL' and 'NL' tables if they exist

# %%
engine = create_engine(f"postgresql://postgres:{db_password}@127.0.0.1:5432/MLB_DB")

data_NL.to_sql(name='national_league', con=engine)
data_AL.to_sql(name='american_league', con=engine)
