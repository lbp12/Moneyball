# %%
from Cleaner import *
from config import db_password

# %% [markdown]
# ## Create the DataFrame

# %% [markdown]
# ### Player Awards
# Up-To-Date data from [Sean Lahman](https://www.seanlahman.com/baseball-archive/statistics/)

# %%
awards = pd.read_csv('Resources/AwardsPlayers.csv').drop(columns=['tie','notes'])
all_awards = reverseLookup(awards)

all_awards.loc[all_awards['awardID']=='Most Valuable Player'].sort_values(by = ['yearID']).tail(11)
# Out:
# Gathering player lookup table. This may take a moment.
#                    Name  mlb_played_first  mlb_played_last   playerID  \
# 761         Kris Bryant            2015.0           2022.0  bryankr01
# 5584  Giancarlo Stanton            2010.0           2022.0  stantmi03
# 124         Jose Altuve            2011.0           2022.0  altuvjo01
# 6423   Christian Yelich            2013.0           2022.0  yelicch01
# 469        Mookie Betts            2014.0           2022.0  bettsmo01
# 384      Cody Bellinger            2017.0           2022.0  bellico01
# 5877         Mike Trout            2011.0           2022.0  troutmi01
# 25           José Abreu            2014.0           2022.0  abreujo02
# 1909    Freddie Freeman            2010.0           2022.0  freemfr01
# 2478       Bryce Harper            2012.0           2022.0  harpebr03
# 4182      Shohei Ohtani            2018.0           2022.0  ohtansh01
#
#                    awardID  yearID lgID
# ...

# %% [markdown]
# ### Merge awards and players dataframes

# %%
data = Merger(all_awards)
data
# Out:
# ............Scraping Data.............
#
# 1982 Time: 1.0445339679718018 Seconds
# 1983 Time: 1.195610761642456 Seconds
# 1984 Time: 1.0407910346984863 Seconds
# 1985 Time: 1.0716478824615479 Seconds
# 1986 Time: 0.9833049774169922 Seconds
#
# .......Approximately 57 Seconds.......
#
# Total Time: 47.08753061294556 Seconds
#         IDfg  Season            Name   Team  Age    G   AB   PA    H   1B  \
# 0    1014396    1982     Robin Yount    MIL   26  156  635  704  210  123
# 1    1014396    1982     Robin Yount    MIL   26  156  635  704  210  123
# 2    1014396    1982     Robin Yount    MIL   26  156  635  704  210  123
# 3    1014396    1982     Robin Yount    MIL   26  156  635  704  210  123
# 4    1014396    1982     Robin Yount    MIL   26  156  635  704  210  123
# ..       ...     ...             ...    ...  ...  ...  ...  ...  ...  ...
# 141    17696    2021    Kevin Newman    PIT   27  148  517  554  117   87
# ...

# %%
count=0
for x in data['lgID'].isna():
    if x == True:
        count += 1      
print(str(count)+' Rows with no Team Names')
empty_league =data.loc[(data['lgID'] != 'NL') & (data['lgID'] != 'AL')]
empty_league['Team'].unique()
# Out:
# 318 Rows with no Team Names
# array(['- - -'], dtype=object)

# %%
print('None of these entries have an MVP')
empty_league.loc[empty_league['awardID'] == 'Most Valuable Player']
# Out:
# None of these entries have an MVP
# Empty DataFrame
# Columns: [IDfg, Season, Name, Team, Age, G, AB, PA, H, 1B, 2B, 3B, HR, R, RBI, BB, IBB, SO, HBP, SF, SH, GDP, SB, CS, AVG, GB, FB, LD, IFFB, Pitches, Balls, Strikes, IFH, BU, BUH, BB%, K%, BB/K, OBP, SLG, OPS, ISO, BABIP, GB/FB, LD%, GB%, FB%, IFFB%, HR/FB, IFH%, BUH%, wOBA, wRAA, wRC, Bat, Fld, Rep, Pos, RAR, WAR, Dol, Spd, wRC+, WPA, -WPA, +WPA, RE24, REW, pLI, phLI, PH, WPA/LI, Clutch, FB% (Pitch), FBv, SL%, SLv, CT%, CTv, CB%, CBv, CH%, CHv, SF%, SFv, KN%, KNv, XX%, PO%, wFB, wSL, wCT, wCB, wCH, wSF, wKN, wFB/C, wSL/C, wCT/C, wCB/C, ...]
# Index: []
#
# [0 rows x 326 columns]

# %%
print('Some have won other awards')
empty_league.loc[empty_league['awardID'] != 'No Award']
# Out:
# Some have won other awards
#       IDfg  Season         Name   Team  Age    G   AB   PA    H  1B  ...  \
# 103   2434    2021  Nelson Cruz  - - -   40  140  513  584  136  82  ...
# 142  14221    2021  Jorge Soler  - - -   29  149  516  602  115  61  ...
# 103   2434    2021  Nelson Cruz  - - -   40  140  513  584  136  82  ...
# 142  14221    2021  Jorge Soler  - - -   29  149  516  602  115  61  ...
#
#        xBA   xSLG  xwOBA  mlb_played_first  mlb_played_last   playerID  \
# 103  0.264  0.512  0.363            2005.0           2022.0   cruzne02
# 142  0.250  0.494  0.359            2014.0           2022.0  solerjo01
# 103  0.264  0.512  0.363            2005.0           2022.0   cruzne02
# 142  0.250  0.494  0.359            2014.0           2022.0  solerjo01
#
#                     awardID  yearID  lgID  MVP
# 103  Roberto Clemente Award  2021.0    ML    0
# 142        World Series MVP  2021.0    ML    0
# 103  Roberto Clemente Award  2021.0    ML    0
# ...

# %% [markdown]
# ### NL MVP Check

# %%
mvpVerify(data)
# Out:
# There are/is 51 unique mvps
# ['Robin Yount' 'Dale Murphy' 'Cal Ripken' 'Ryne Sandberg' 'Don Mattingly'
#  'Mike Schmidt' 'George Bell' 'Andre Dawson' 'Jose Canseco' 'Kirk Gibson'
#  'Kevin Mitchell' 'Rickey Henderson' 'Barry Bonds' 'Terry Pendleton'
#  'Frank Thomas' 'Jeff Bagwell' 'Barry Larkin' 'Mo Vaughn' 'Ken Caminiti'
#  'Juan Gonzalez' 'Larry Walker' 'Sammy Sosa' 'Chipper Jones'
#  'Ivan Rodriguez' 'Jason Giambi' 'Jeff Kent' 'Ichiro Suzuki'
#  'Miguel Tejada' 'Alex Rodriguez' 'Vladimir Guerrero' 'Albert Pujols'
#  'Ryan Howard' 'Justin Morneau' 'Jimmy Rollins' 'Dustin Pedroia'
#  'Joe Mauer' 'Josh Hamilton' 'Joey Votto' 'Ryan Braun' 'Buster Posey'
#  'Miguel Cabrera' 'Mike Trout' 'Bryce Harper' 'Josh Donaldson'
#  'Kris Bryant' 'Jose Altuve' 'Giancarlo Stanton' 'Mookie Betts'
#  'Christian Yelich' 'Cody Bellinger' 'Shohei Ohtani']
#        IDfg  Season           Name Team  Age    G   AB   PA    H   1B  ...  \
# ...

# %% [markdown]
# ## Export to Postgre
#
# Make sure this connection string work:
#
#  1) Verify connection points, and import config with variable db_password=YOUR_POSTGRE_PASSWORD
#
#  2) Creating a Raw_Stats database in Postgre
#
#  3) Drop 'AL' and 'NL' tables if they exist

# %%
engine = create_engine(f"postgresql://postgres:{db_password}@127.0.0.1:5432/Raw_Stats")

data_NL.to_sql(name='NL', con=engine)
data_AL.to_sql(name='AL', con=engine)
# Out:
# 786
