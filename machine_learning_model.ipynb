# %%
# Import packages and libraries

from pybaseball import batting_stats_range
from pybaseball import batting_stats
from pathlib import Path
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read in batting_df

batting_df = pd.read_csv('batting_df.csv')
batting_df.head()
# Out:
#    Unnamed: 0              Name    G   AB   PA    H   1B  2B  3B  HR  ...  \
# 0           0      Bryce Harper  153  521  654  172   91  38   1  42  ...
# 1           3        Mike Trout  159  575  682  172   93  32   6  41  ...
# 2           5    Josh Donaldson  158  620  711  184  100  41   2  41  ...
# 3           1        Joey Votto  158  545  695  171  107  33   2  29  ...
# 4           2  Paul Goldschmidt  159  567  695  182  109  38   2  33  ...
#
#    maxEV  HardHit  HardHit%  Events  CStr%   CSW%    xBA   xSLG  xwOBA  MVP
# 0  116.0      188     0.477     394  0.118  0.226  0.292  0.544  0.418    0
# 1  117.7      205     0.486     422  0.207  0.282  0.297  0.588  0.422    0
# 2  113.6      232     0.465     499  0.145  0.255  0.280  0.546  0.390    1
# 3  109.3      175     0.425     412  0.177  0.254  0.289  0.541  0.422    0
# 4  114.0      197     0.465     424  0.181  0.266  0.279  0.558  0.403    0
#
# [5 rows x 260 columns]

# %%
# Dropping 'Name' column

batting_df = batting_df.drop(columns='Name', axis=1)
batting_df.head()
# Out:
#    Unnamed: 0    G   AB   PA    H   1B  2B  3B  HR    R  ...  maxEV  HardHit  \
# 0           0  153  521  654  172   91  38   1  42  118  ...  116.0      188
# 1           3  159  575  682  172   93  32   6  41  104  ...  117.7      205
# 2           5  158  620  711  184  100  41   2  41  122  ...  113.6      232
# 3           1  158  545  695  171  107  33   2  29   95  ...  109.3      175
# 4           2  159  567  695  182  109  38   2  33  103  ...  114.0      197
#
#    HardHit%  Events  CStr%   CSW%    xBA   xSLG  xwOBA  MVP
# 0     0.477     394  0.118  0.226  0.292  0.544  0.418    0
# 1     0.486     422  0.207  0.282  0.297  0.588  0.422    0
# 2     0.465     499  0.145  0.255  0.280  0.546  0.390    1
# 3     0.425     412  0.177  0.254  0.289  0.541  0.422    0
# 4     0.465     424  0.181  0.266  0.279  0.558  0.403    0
#
# [5 rows x 259 columns]

# %%
# Split our preprocessed data into our features and target arrays


y = batting_df["MVP"].values
X = batting_df.drop(["MVP"],1).values
# Out:
# C:\Users\CDAbernethy02\Anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """

# %%
# Split the preprocessed data into a training and testing dataset

X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
# Create a Logistic Regression Model

classifier = LogisticRegression(solver='lbfgs')
classifier
# Out:
# LogisticRegression()

# %%
# Train the data
classifier.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10096\605911896.py in <module>
#       1 # Train the data
# ----> 2 classifier.fit(X_train, y_train)
#
# ~\Anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1512             dtype=_dtype,
#    1513             order="C",
# -> 1514             accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1515         )
#    1516         check_classification_targets(y)
#
# ~\Anaconda3\envs\mlenv\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
#     582             out = X, y
#     583
#
# ~\Anaconda3\envs\mlenv\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     974         ensure_min_samples=ensure_min_samples,
#     975         ensure_min_features=ensure_min_features,
# --> 976         estimator=estimator,
#     977     )
#     978
#
# ~\Anaconda3\envs\mlenv\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     744                     array = array.astype(dtype, casting="unsafe", copy=False)
#     745                 else:
# --> 746                     array = np.asarray(array, order=order, dtype=dtype)
#     747             except ComplexWarning as complex_warning:
#     748                 raise ValueError(
#
# ValueError: could not convert string to float: '$30.0'
