# %%
# Import packages and libraries

from pybaseball import batting_stats_range
from pybaseball import batting_stats
from pathlib import Path
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
from imblearn.combine import SMOTEENN
from collections import Counter

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read in batting_df

batting_df = pd.read_csv('batting_df.csv')
batting_df.head()
# Out:
#    Unnamed: 0              Name    G   AB   PA    H   1B  2B  3B  HR  ...  \
# 0           0      Bryce Harper  153  521  654  172   91  38   1  42  ...
# 1           3        Mike Trout  159  575  682  172   93  32   6  41  ...
# 2           5    Josh Donaldson  158  620  711  184  100  41   2  41  ...
# 3           1        Joey Votto  158  545  695  171  107  33   2  29  ...
# 4           2  Paul Goldschmidt  159  567  695  182  109  38   2  33  ...
#
#     wOBA  wRAA  wRC   Bat  Fld   Rep   Pos   RAR  WAR  MVP
# 0  0.461  77.3  151  74.1 -4.0  19.1  -6.1  87.8  9.3    0
# 1  0.415  55.4  132  55.7  4.7  19.9   1.9  87.6  9.3    0
# 2  0.398  47.9  128  44.7  8.6  20.8   1.5  82.1  8.7    1
# 3  0.427  63.1  141  59.8  0.0  20.3 -11.8  68.3  7.3    0
# 4  0.418  57.9  136  51.1  4.6  20.3 -12.1  68.1  7.2    0
#
# [5 rows x 58 columns]

# %%
# Dropping 'Name' column

batting_df = batting_df.drop(columns='Name', axis=1)
batting_df.head()
# Out:
#    Unnamed: 0    G   AB   PA    H   1B  2B  3B  HR    R  ...   wOBA  wRAA  \
# 0           0  153  521  654  172   91  38   1  42  118  ...  0.461  77.3
# 1           3  159  575  682  172   93  32   6  41  104  ...  0.415  55.4
# 2           5  158  620  711  184  100  41   2  41  122  ...  0.398  47.9
# 3           1  158  545  695  171  107  33   2  29   95  ...  0.427  63.1
# 4           2  159  567  695  182  109  38   2  33  103  ...  0.418  57.9
#
#    wRC   Bat  Fld   Rep   Pos   RAR  WAR  MVP
# 0  151  74.1 -4.0  19.1  -6.1  87.8  9.3    0
# 1  132  55.7  4.7  19.9   1.9  87.6  9.3    0
# 2  128  44.7  8.6  20.8   1.5  82.1  8.7    1
# 3  141  59.8  0.0  20.3 -11.8  68.3  7.3    0
# 4  136  51.1  4.6  20.3 -12.1  68.1  7.2    0
#
# [5 rows x 57 columns]

# %%
# Assigning independent and dependent variables 

x_cols = [i for i in batting_df.columns if i not in ('MVP')]
X = batting_df[x_cols]
y = batting_df['MVP']

# %%
# Split data into training and testing sets 

X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
# Create an instance of SMOTEENN, which resamples the dataset 

smote_enn = SMOTEENN(random_state=0)
X_resampled, y_resampled = smote_enn.fit_resample(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16648\4032526249.py in <module>
#       2
#       3 smote_enn = SMOTEENN(random_state=0)
# ----> 4 X_resampled, y_resampled = smote_enn.fit_resample(X, y)
#
# ~\Anaconda3\envs\mlenv\lib\site-packages\imblearn\base.py in fit_resample(self, X, y)
#      81         )
#      82
# ---> 83         output = self._fit_resample(X, y)
#      84
#      85         y_ = (label_binarize(output[1], np.unique(y))
#
# ~\Anaconda3\envs\mlenv\lib\site-packages\imblearn\combine\_smote_enn.py in _fit_resample(self, X, y)
#     142         self.sampling_strategy_ = self.sampling_strategy
#     143
# --> 144         X_res, y_res = self.smote_.fit_resample(X, y)
#     145         return self.enn_.fit_resample(X_res, y_res)
#
# ~\Anaconda3\envs\mlenv\lib\site-packages\imblearn\base.py in fit_resample(self, X, y)
#      81         )
#      82
# ---> 83         output = self._fit_resample(X, y)
#      84
#      85         y_ = (label_binarize(output[1], np.unique(y))
#
# ~\Anaconda3\envs\mlenv\lib\site-packages\imblearn\over_sampling\_smote.py in _fit_resample(self, X, y)
#     730
#     731             self.nn_k_.fit(X_class)
# --> 732             nns = self.nn_k_.kneighbors(X_class, return_distance=False)[:, 1:]
#     733             X_new, y_new = self._make_samples(
#     734                 X_class, y.dtype, class_sample, X_class, nns, n_samples, 1.0
#
# ~\Anaconda3\envs\mlenv\lib\site-packages\sklearn\neighbors\_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     727             raise ValueError(
#     728                 "Expected n_neighbors <= n_samples, "
# --> 729                 " but n_samples = %d, n_neighbors = %d" % (n_samples_fit, n_neighbors)
#     730             )
#     731
#
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 1, n_neighbors = 6
